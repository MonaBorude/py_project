# %%
# Objective :
    
# Exploratory Data Analysis   [EDA]
# Data Preprocessing
# Data Cleaning 

# Python
# Libraries :
# 1. numpy : Arithmatics
# 2. pandas: Data Manipulation
# 3. matplotlib/seaborn : visualization

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read data 

df = pd.read_csv('Comcast_telecom_complaints_data.csv')

# %%
# 1. Open File

df
# Out:
#      Ticket #                                 Customer Complaint      Date  \
# 0      250635                      Comcast Cable Internet Speeds  22-04-15
# 1      223441       Payment disappear - service got disconnected  04-08-15
# 2      242732                                  Speed and Service  18-04-15
# 3      277946  Comcast Imposed a New Usage Cap of 300GB that ...  05-07-15
# 4      307175         Comcast not working and no service to boot  26-05-15
# ...       ...                                                ...       ...
# 2219   213550                               Service Availability  04-02-15
# 2220   318775         Comcast Monthly Billing for Returned Modem  06-02-15
# 2221   331188                            complaint about comcast  06-09-15
# 2222   360489             Extremely unsatisfied Comcast customer  23-06-15
# 2223   363614               Comcast, Ypsilanti MI Internet Speed  24-06-15
#
# ...

# %%
# 2. Display Shape of data

df.shape
# Out:
# (2224, 11)

# %%
# 3. Display Columns

df.columns
# Out:
# Index(['Ticket #', 'Customer Complaint', 'Date', 'Date_month_year', 'Time',
#        'Received Via', 'City', 'State', 'Zip code', 'Status',
#        'Filing on Behalf of Someone'],
#       dtype='object')

# %%
# 4. Display first rows of data. : head()

df.head(10)
# Out:
#   Ticket #                                 Customer Complaint      Date  \
# 0   250635                      Comcast Cable Internet Speeds  22-04-15
# 1   223441       Payment disappear - service got disconnected  04-08-15
# 2   242732                                  Speed and Service  18-04-15
# 3   277946  Comcast Imposed a New Usage Cap of 300GB that ...  05-07-15
# 4   307175         Comcast not working and no service to boot  26-05-15
# 5   338519  ISP Charging for arbitrary data limits with ov...  06-12-15
# 6   361148      Throttling service and unreasonable data caps  24-06-15
# 7   359792  Comcast refuses to help troubleshoot and corre...  23-06-15
# 8   318072                           Comcast extended outages  06-01-15
# 9   371214  Comcast Raising Prices and Not Being Available...  28-06-15
#
#   Date_month_year         Time        Received Via      City       State  \
# 0       22-Apr-15   3:53:50 PM  Customer Care Call  Abingdon    Maryland
# ...

# %%
# Display last few rows : tail()

df.tail(10)
# Out:
#      Ticket #                               Customer Complaint      Date  \
# 2214   310847                 Comcast Internet Service quality  28-05-15
# 2215   360946                           Comcast unfair pricing  24-06-15
# 2216   363852                       High Internet & Cable Bill  25-06-15
# 2217   254488                   problems with internet service  24-04-15
# 2218   338192  Speed throttling, speeds not at promised output  06-12-15
# 2219   213550                             Service Availability  04-02-15
# 2220   318775       Comcast Monthly Billing for Returned Modem  06-02-15
# 2221   331188                          complaint about comcast  06-09-15
# 2222   360489           Extremely unsatisfied Comcast customer  23-06-15
# 2223   363614             Comcast, Ypsilanti MI Internet Speed  24-06-15
#
#      Date_month_year         Time        Received Via        City  \
# 2214       28-May-15   8:56:14 AM            Internet        York
# ...

# %%
# Display Random Rows : sample()

df.sample(5)
# Out:
#      Ticket #                                 Customer Complaint      Date  \
# 1051   290536                                  Comcast Data Caps  14-05-15
# 1672   348029                         Poor Speed and Reliability  18-06-15
# 682    342774                                           Data cap  16-06-15
# 1777   241909  Comcast Xfinity Charges Consumer for Troublesh...  17-04-15
# 532    339894                       Xfinity Comcast hbogo on ps4  14-06-15
#
#      Date_month_year         Time        Received Via         City  \
# 1051       14-May-15   4:49:54 PM  Customer Care Call    Knoxville
# 1672       18-Jun-15  10:00:47 AM            Internet     Richmond
# 682        16-Jun-15  10:29:45 AM  Customer Care Call  Fayettevile
# 1777       17-Apr-15   3:58:33 PM            Internet     San Jose
# 532        14-Jun-15  12:37:53 PM            Internet    Dartmouth
#
#               State  Zip code  Status Filing on Behalf of Someone
# ...

# %%
# Display information of data : info()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2224 entries, 0 to 2223
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Ticket #                     2224 non-null   object
#  1   Customer Complaint           2224 non-null   object
#  2   Date                         2224 non-null   object
#  3   Date_month_year              2224 non-null   object
#  4   Time                         2224 non-null   object
#  5   Received Via                 2224 non-null   object
#  6   City                         2224 non-null   object
#  7   State                        2224 non-null   object
#  8   Zip code                     2224 non-null   int64
#  9   Status                       2224 non-null   object
#  10  Filing on Behalf of Someone  2224 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 191.3+ KB

# %%
# Let us find Categorical Features [columns]

# %%
df['Date'].nunique()       # 91
# Out:
# 91

# %%
df['Received Via'].unique() # 2
# Out:
# array(['Customer Care Call', 'Internet'], dtype=object)

# %%
df['City'].nunique()  # 928
# Out:
# 928

# %%
df['State'].unique()  # 43
# Out:
# array(['Maryland', 'Georgia', 'Michigan', 'California', 'New Mexico',
#        'Indiana', 'Virginia', 'Illinois', 'Pennsylvania', 'Massachusetts',
#        'Oregon', 'Texas', 'New Hampshire', 'Minnesota', 'Tennessee',
#        'Colorado', 'Florida', 'Alabama', 'Washington', 'New York',
#        'New Jersey', 'Maine', 'Missouri', 'West Virginia', 'Montana',
#        'Mississippi', 'Connecticut', 'Vermont', 'Kentucky',
#        'South Carolina', 'Ohio', 'Utah', 'Delaware', 'Arkansas', 'Nevada',
#        'Louisiana', 'Kansas', 'Arizona', 'North Carolina', 'Rhode Island',
#        'District Of Columbia', 'District of Columbia', 'Iowa'],
#       dtype=object)

# %%
df['Zip code'].nunique()   # 1543
# Out:
# 1543

# %%
df['Status'].unique()
# Out:
# array(['Closed', 'Open', 'Solved', 'Pending'], dtype=object)

# %%
# Display count of each status

df['Status'].value_counts()
# Out:
# Solved     973
# Closed     734
# Open       363
# Pending    154
# Name: Status, dtype: int64

# %%
# Replace closed woth Solved        and     pending with open

# %%
# List Comprehension

# list_name = [var  if else   for i in list]

# %%
df['New Status'] = ['Solved'   if i == 'Solved' or i == 'Closed'  else 'Open'   for i in df['Status'] ]

# %%
df.head()
# Out:
#   Ticket #                                 Customer Complaint      Date  \
# 0   250635                      Comcast Cable Internet Speeds  22-04-15
# 1   223441       Payment disappear - service got disconnected  04-08-15
# 2   242732                                  Speed and Service  18-04-15
# 3   277946  Comcast Imposed a New Usage Cap of 300GB that ...  05-07-15
# 4   307175         Comcast not working and no service to boot  26-05-15
#
#   Date_month_year         Time        Received Via      City     State  \
# 0       22-Apr-15   3:53:50 PM  Customer Care Call  Abingdon  Maryland
# 1       04-Aug-15  10:22:56 AM            Internet   Acworth   Georgia
# 2       18-Apr-15   9:55:47 AM            Internet   Acworth   Georgia
# 3       05-Jul-15  11:59:35 AM            Internet   Acworth   Georgia
# 4       26-May-15   1:25:26 PM            Internet   Acworth   Georgia
#
#    Zip code  Status Filing on Behalf of Someone New Status
# ...

# %%
# Remove Column Status   drop()

df1 = df.drop('Status', axis = 1)

# %%
df1.head(1)
# Out:
#   Ticket #             Customer Complaint      Date Date_month_year  \
# 0   250635  Comcast Cable Internet Speeds  22-04-15       22-Apr-15
#
#          Time        Received Via      City     State  Zip code  \
# 0  3:53:50 PM  Customer Care Call  Abingdon  Maryland     21009
#
#   Filing on Behalf of Someone New Status
# 0                          No     Solved

# %%
# Data Analysis :

# %%
# 1. Display Complaint Status

df1['New Status'].value_counts()
# Out:
# Solved    1707
# Open       517
# Name: New Status, dtype: int64

# %%
# plot bar plot.

plt.figure(figsize = (4,4))
df1['New Status'].value_counts().plot.bar()
plt.xlabel('Complaint Status')
plt.ylabel('Complaint Count')
plt.title('Customer Complaint Status')
# Out:
# Text(0.5, 1.0, 'Customer Complaint Status')

# %%
# 2.# plot " Daily Complaint chart "

df1['Date'].value_counts().plot()

# %%
# 3.  City wise complaint [ top 10 ]

df1['City'].value_counts()[ : 10]
# Out:
# Atlanta         63
# Chicago         47
# Knoxville       36
# Houston         33
# Jacksonville    31
# Philadelphia    25
# Denver          22
# Nashville       22
# Miami           22
# Indianapolis    21
# Name: City, dtype: int64

# %%
df1['City'].value_counts()[ : 10].plot.bar()

# %%
# 4. Display states with max complaints

df1['State'].value_counts()[ : 10]
# Out:
# Georgia         288
# Florida         240
# California      220
# Illinois        164
# Tennessee       143
# Pennsylvania    130
# Michigan        115
# Washington       98
# Colorado         80
# Maryland         78
# Name: State, dtype: int64

# %%
# 5. Display State wise Complaint status.

df1.groupby(['State'])['New Status'].value_counts().unstack()
# Out:
# New Status            Open  Solved
# State
# Alabama                9.0    17.0
# Arizona                6.0    14.0
# Arkansas               NaN     6.0
# California            61.0   159.0
# Colorado              22.0    58.0
# Connecticut            3.0     9.0
# Delaware               4.0     8.0
# District Of Columbia   2.0    14.0
# District of Columbia   NaN     1.0
# Florida               39.0   201.0
# Georgia               80.0   208.0
# Illinois              29.0   135.0
# Indiana                9.0    50.0
# Iowa                   NaN     1.0
# Kansas                 1.0     1.0
# Kentucky               3.0     4.0
# Louisiana              1.0    12.0
# Maine                  2.0     3.0
# Maryland              15.0    63.0
# Massachusetts         11.0    50.0
# Michigan              23.0    92.0
# Minnesota              4.0    29.0
# Mississippi           16.0    23.0
# Missouri               1.0     3.0
# Montana                NaN     1.0
# ...

# %%
plt.figure(figsize = (15, 8))
df1.groupby(['State'])['New Status'].value_counts().unstack().plot.bar()
plt.show()

# %%
# 1. Display No of complaints received through each channel.
# 2. State wise Compalaint channels.
# 3. Display channel wise complaint status.
# Out:
# Index(['Ticket #', 'Customer Complaint', 'Date', 'Date_month_year', 'Time',
#        'Received Via', 'City', 'State', 'Zip code',
#        'Filing on Behalf of Someone', 'New Status'],
#       dtype='object')

# %%
df1['Received Via'].value_counts()
# Out:
# Customer Care Call    1119
# Internet              1105
# Name: Received Via, dtype: int64

# %%
df1.groupby('State')['Received Via'].value_counts().unstack()

# %%
df1.groupby('Received Via')['New Status'].value_counts().unstack()
# Out:
# New Status          Open  Solved
# Received Via
# Customer Care Call   255     864
# Internet             262     843
